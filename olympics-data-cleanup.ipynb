# %%
import pandas as pd

# %%
df_olympics = pd.read_csv('data/bios_raw.csv')
df_olympics.sample(3)
# Out:
#                            Roles     Sex                  Full name  \
# 69907  Competed in Olympic Games    Male      Franz Paul•Nettelbeck
# 24950  Competed in Olympic Games    Male    Albert Alexandre•Parsis
# 49318  Competed in Olympic Games  Female  Karin Doris•Brandes Pérez
#
#              Used name                                   Born  \
# 69907  Paul•Nettelbeck  23 April 1889 in Berlin, Berlin (GER)
# 24950    Albert•Parsis   2 June 1890 in Tourcoing, Nord (FRA)
# 49318    Karin•Brandes  26 September 1967 in Lima, Lima (PER)
#
#                                             Died      NOC  athlete_id  \
# 69907   14 June 1963 in Salzburg, Salzburg (AUT)  Germany       70428
# 24950  24 February 1980 in Tourcoing, Nord (FRA)   France       25139
# 49318                                        NaN     Peru       49675
#
#          Measurements                               Affiliations  \
# 69907             NaN  Charlottenburger Sport-Club, Berlin (GER)
# 24950             NaN              US Tourcoing, Tourcoing (FRA)
# 49318  169 cm / 58 kg                                        NaN
#
#       Nick/petnames Title(s) Other names Nationality Original name Name order
# 69907           NaN      NaN         NaN         NaN           NaN        NaN
# 24950           NaN      NaN         NaN         NaN           NaN        NaN
# 49318           NaN      NaN         NaN         NaN           NaN        NaN

# %%
# make a copy of df
df = df_olympics.copy()

# %%
# cleanup full name remove the '•' string
df["name"] = df['Full name'].str.replace('•',' ')
# df[["name", "Full name"]].sample(5)

# %%
df.sample(4)

# df.info()
# Out:
#                            Roles     Sex              Full name  \
# 49718  Competed in Olympic Games  Female       Yu Fen "May"•Ooi
# 85032  Competed in Olympic Games    Male  Piotr Władysław•Fijas
# 38847  Competed in Olympic Games    Male          Kjetil•Undset
# 68795  Competed in Olympic Games    Male     Roger George•Mills
#
#            Used name                                          Born Died  \
# 49718        May•Ooi                                  24 June 1976  NaN
# 85032    Piotr•Fijas  27 June 1958 in Bielsko-Biała, Śląskie (POL)  NaN
# 38847  Kjetil•Undset   24 August 1970 in Stavanger, Rogaland (NOR)  NaN
# 68795    Roger•Mills    11 February 1948 in Romford, England (GBR)  NaN
#
#                  NOC  athlete_id    Measurements  \
# 49718      Singapore       50076             NaN
# 85032         Poland       85710  189 cm / 80 kg
# 38847         Norway       39150  201 cm / 95 kg
# 68795  Great Britain       69312  182 cm / 74 kg
#
#                                             Affiliations Nick/petnames  \
# 49718           People's Association Youth Swimming Club           NaN
# 85032  BBTS Włókniarz Bielsko-Biała, Bielsko-Biała (POL)           NaN
# 38847                  Stavanger Roklub, Stavanger (NOR)           NaN
# 68795                 Ilford Athletic Club, Ilford (GBR)           NaN
#
#       Title(s) Other names Nationality Original name Name order  \
# 49718      NaN         NaN         NaN           NaN        NaN
# 85032      NaN         NaN         NaN           NaN        NaN
# 38847      NaN         NaN         NaN           NaN        NaN
# 68795      NaN         NaN         NaN           NaN        NaN
#
#                         name
# 49718       Yu Fen "May" Ooi
# 85032  Piotr Władysław Fijas
# 38847          Kjetil Undset
# 68795     Roger George Mills

# %%
# split measurements into height_cm and weight_kg
df[['height_cm', 'weight_kg']] = df["Measurements"].str.split('/', expand=True)

# %%
# find total rows in which there is kg value in height_cm
# len(df[df["height_cm"].astype('str').str.contains("kg")])
# 1182

# 180 cm / 80 kg
# 76 kg

df['height_cm'] = pd.to_numeric(df['height_cm'].str.strip(" cm"), errors="coerce")

df['weight_kg'] = pd.to_numeric(df['weight_kg'].str.strip(' kg'), errors="coerce")

# %%
df[['name', 'Measurements','height_cm','weight_kg']].sample(4)
# Out:
#                                   name    Measurements  height_cm  weight_kg
# 6936    William Edward "Bill" Robinson  180 cm / 71 kg      180.0       71.0
# 31059    John Frederick Bissinger, Jr.          180 cm      180.0        NaN
# 117690                  Guntis Galviņš  185 cm / 87 kg      185.0       87.0
# 143611                  Caroline Marks             NaN        NaN        NaN

# %%
# df[["height_cm", "weight_kg"]].sample(8)
# df[df["height_cm"].notna() & df["weight_kg"].isna()][["name","height_cm", "weight_kg"]].sample(10)

# df[df["weight_kg"].isna()][["name","height_cm", "weight_kg"]]
# df[df["Measurements"].str.split('/').str.len() == 1 & df["Measurements"].str.split('/').str.contains('kg')]

# df[df["Measurements"].str.contains("kg") & ~df["Measurements"].str.contains('cm')]
# Out:
#                             Roles     Sex                 Full name  \
# 165     Competed in Olympic Games  Female     Patricia Akosua•Offel
# 289     Competed in Olympic Games    Male               Ángel•Bello
# 290     Competed in Olympic Games    Male        Claudio A.•Pafundi
# 1128    Competed in Olympic Games    Male        Jeffrey O.•Alleyne
# 1132    Competed in Olympic Games    Male       Edward "Ed"•Beattie
# ...                           ...     ...                       ...
# 143193  Competed in Olympic Games    Male          Rejepbaý•Rejepow
# 143225  Competed in Olympic Games    Male               Chen•Po-Jen
# 143542  Competed in Olympic Games  Female          Nefeli•Papadakis
# 143852  Competed in Olympic Games    Male         Kyle Douglas•Dake
# 144122  Competed in Olympic Games  Female  Scarleth•Ucelo Marroquín
#
#                Used name                                             Born  \
# 165       Patricia•Offel                                 19 December 1971
# 289          Ángel•Bello         9 January 1951 in Vigo, Pontevedra (ESP)
# 290      Claudio•Pafundi                                  31 January 1962
# 1128     Jeffrey•Alleyne  25 June 1938 in Bridgetown, Saint Michael (BAR)
# 1132          Ed•Beattie       4 February 1934 in Kilsyth, Scotland (GBR)
# ...                  ...                                              ...
# 143193  Rejepbaý•Rejepow                                 23 February 1992
# 143225       Chen•Po-Jen                                      11 May 1998
# 143542  Nefeli•Papadakis        2 October 1998 in Chicago, Illinois (USA)
# 143852         Kyle•Dake       25 February 1991 in Ithaca, New York (USA)
# 144122    Scarleth•Ucelo                                     7 April 2000
#
#                 Died             NOC  athlete_id Measurements  \
# 165              NaN           Ghana         166       120 kg
# 289     13 June 2013       Argentina         290        65 kg
# 290              NaN       Argentina         291        76 kg
# 1128             NaN          Canada        1135        71 kg
# 1132             NaN          Canada        1139        60 kg
# ...              ...             ...         ...          ...
# 143193           NaN    Turkmenistan      146829        81 kg
# 143225           NaN  Chinese Taipei      146865        96 kg
# 143542           NaN   United States      147195        78 kg
# 143852           NaN   United States      147508        79 kg
# 144122           NaN       Guatemala      147795       114 kg
#
#                                              Affiliations Nick/petnames  \
# 165                                                   NaN           NaN
# 289     Tiro Federal de Lomas de Zamora, Lomas de Zamo...           NaN
# 290     Tiro Federal General José de San Martín, San M...           NaN
# 1128                                                  NaN           NaN
# 1132                                                  NaN           NaN
# ...                                                   ...           ...
# 143193                                                NaN           NaN
# 143225                                                NaN           NaN
# 143542                                                NaN           NaN
# 143852                                                NaN           NaN
# 144122                                                NaN           NaN
#
#        Title(s) Other names Nationality Original name Name order  \
# 165         NaN         NaN         NaN           NaN        NaN
# 289         NaN         NaN         NaN           NaN        NaN
# 290         NaN         NaN         NaN           NaN        NaN
# 1128        NaN         NaN         NaN           NaN        NaN
# 1132        NaN         NaN         NaN           NaN        NaN
# ...         ...         ...         ...           ...        ...
# 143193      NaN         NaN         NaN           NaN        NaN
# 143225      NaN         NaN         NaN          陳•柏任   Oriental
# 143542      NaN         NaN         NaN           NaN        NaN
# 143852      NaN         NaN         NaN           NaN        NaN
# 144122      NaN         NaN         NaN           NaN        NaN
#
#                             name height_cm weight_kg
# 165        Patricia Akosua Offel    120 kg       NaN
# 289                  Ángel Bello     65 kg       NaN
# 290           Claudio A. Pafundi     76 kg       NaN
# 1128          Jeffrey O. Alleyne     71 kg       NaN
# 1132         Edward "Ed" Beattie     60 kg       NaN
# ...                          ...       ...       ...
# 143193          Rejepbaý Rejepow     81 kg       NaN
# 143225               Chen Po-Jen     96 kg       NaN
# 143542          Nefeli Papadakis     78 kg       NaN
# 143852         Kyle Douglas Dake     79 kg       NaN
# 144122  Scarleth Ucelo Marroquín    114 kg       NaN
#
# [1182 rows x 19 columns]

# %%
df.iloc[143193,:]
# Out:
# Roles            Competed in Olympic Games
# Sex                                   Male
# Full name                 Rejepbaý•Rejepow
# Used name                 Rejepbaý•Rejepow
# Born                      23 February 1992
# Died                                   NaN
# NOC                           Turkmenistan
# athlete_id                          146829
# Measurements                         81 kg
# Affiliations                           NaN
# Nick/petnames                          NaN
# Title(s)                               NaN
# Other names                            NaN
# Nationality                            NaN
# Original name                          NaN
# Name order                             NaN
# name                      Rejepbaý Rejepow
# height_cm                            81 kg
# weight_kg                              NaN
# Name: 143193, dtype: object

# %%
# born and dates clearing
df.sample(5)

df["born_date"] = df["Born"].str.extract(r"(\d{1,2}\s\w+\s\d{4})")

# %%
df
# Out:
#                                             Roles     Sex  \
# 0                       Competed in Olympic Games    Male
# 1                       Competed in Olympic Games    Male
# 2       Competed in Olympic Games • Administrator    Male
# 3                       Competed in Olympic Games    Male
# 4                       Competed in Olympic Games    Male
# ...                                           ...     ...
# 145495                  Competed in Olympic Games  Female
# 145496                  Competed in Olympic Games  Female
# 145497                  Competed in Olympic Games  Female
# 145498                  Competed in Olympic Games    Male
# 145499                Non-starter • Administrator    Male
#
#                                                 Full name  \
# 0       François Joseph Marie Antoine "Jean-François"•...
# 1                                 Arnaud Benjamin•Boetsch
# 2                             Jean Laurent Robert•Borotra
# 3                    Jacques Marie Stanislas Jean•Brugnon
# 4                                      Henry Albert•Canet
# ...                                                   ...
# 145495                                  Polina•Luchnikova
# 145496                     Valeriya Sergeyevna•Merkusheva
# 145497                                    Yuliya•Smirnova
# 145498                                     André•Foussard
# 145499                      William Berge "Bill"•Phillips
#
#                     Used name  \
# 0       Jean-François•Blanchy
# 1              Arnaud•Boetsch
# 2                Jean•Borotra
# 3             Jacques•Brugnon
# 4                Albert•Canet
# ...                       ...
# 145495      Polina•Luchnikova
# 145496    Valeriya•Merkusheva
# 145497        Yuliya•Smirnova
# 145498         André•Foussard
# 145499          Bill•Phillips
#
#                                                      Born  \
# 0             12 December 1886 in Bordeaux, Gironde (FRA)
# 1                  1 April 1969 in Meulan, Yvelines (FRA)
# 2       13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3                 11 May 1895 in Paris VIIIe, Paris (FRA)
# 4              17 April 1878 in Wandsworth, England (GBR)
# ...                                                   ...
# 145495         30 January 2002 in Serov, Sverdlovsk (RUS)
# 145496  20 September 1999 in Moskva (Moscow), Moskva (...
# 145497            8 May 1998 in Kotlas, Arkhangelsk (RUS)
# 145498            19 May 1899 in Niort, Deux-Sèvres (FRA)
# 145499  15 July 1913 in Dulwich Hill, New South Wales ...
#
#                                                      Died        NOC  \
# 0       2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...     France
# 1                                                     NaN     France
# 2       17 July 1994 in Arbonne, Pyrénées-Atlantiques ...     France
# 3                   20 March 1978 in Monaco, Monaco (MON)     France
# 4                 25 July 1930 in Paris VIIe, Paris (FRA)     France
# ...                                                   ...        ...
# 145495                                                NaN        ROC
# 145496                                                NaN        ROC
# 145497                                                NaN        ROC
# 145498          18 March 1986 in Niort, Deux-Sèvres (FRA)     France
# 145499   20 October 2003 in Sydney, New South Wales (AUS)  Australia
#
#         athlete_id    Measurements  \
# 0                1             NaN
# 1                2  183 cm / 76 kg
# 2                3  183 cm / 76 kg
# 3                4  168 cm / 64 kg
# 4                5             NaN
# ...            ...             ...
# 145495      149222  167 cm / 61 kg
# 145496      149223  168 cm / 65 kg
# 145497      149224  163 cm / 55 kg
# 145498      149225          166 cm
# 145499      149814             NaN
#
#                                        Affiliations  \
# 0                                               NaN
# 1                Racing Club de France, Paris (FRA)
# 2                                  TCP, Paris (FRA)
# 3               Sporting club de Paris, Paris (FRA)
# 4                                  TCP, Paris (FRA)
# ...                                             ...
# 145495                            Agidel, Ufa (RUS)
# 145496  SKIF Nizhny Novgorod, Nizhny Novgorod (RUS)
# 145497                            Agidel, Ufa (RUS)
# 145498                  Beauvoisine FC, Rouen (FRA)
# 145499                                          NaN
#
#                                      Nick/petnames Title(s) Other names  \
# 0                                              NaN      NaN         NaN
# 1                                              NaN      NaN         NaN
# 2       Le Basque Bondissant (The Bounding Basque)      NaN         NaN
# 3                                             Toto      NaN         NaN
# 4                                              NaN      NaN         NaN
# ...                                            ...      ...         ...
# 145495                                         NaN      NaN         NaN
# 145496                                         NaN      NaN         NaN
# 145497                                         NaN      NaN         NaN
# 145498                                         NaN      NaN         NaN
# 145499                                         NaN      NaN         NaN
#
#        Nationality                Original name Name order  \
# 0              NaN                          NaN        NaN
# 1              NaN                          NaN        NaN
# 2              NaN                          NaN        NaN
# 3              NaN                          NaN        NaN
# 4              NaN                          NaN        NaN
# ...            ...                          ...        ...
# 145495         NaN                          NaN        NaN
# 145496         NaN  Валерия Сергеевна•Меркушева        NaN
# 145497         NaN                Юлия•Смирнова        NaN
# 145498         NaN                          NaN        NaN
# 145499         NaN                          NaN        NaN
#
#                                                      name  height_cm  \
# 0       François Joseph Marie Antoine "Jean-François" ...        NaN
# 1                                 Arnaud Benjamin Boetsch      183.0
# 2                             Jean Laurent Robert Borotra      183.0
# 3                    Jacques Marie Stanislas Jean Brugnon      168.0
# 4                                      Henry Albert Canet        NaN
# ...                                                   ...        ...
# 145495                                  Polina Luchnikova      167.0
# 145496                     Valeriya Sergeyevna Merkusheva      168.0
# 145497                                    Yuliya Smirnova      163.0
# 145498                                     André Foussard      166.0
# 145499                      William Berge "Bill" Phillips        NaN
#
#         weight_kg          born_date
# 0             NaN   12 December 1886
# 1            76.0       1 April 1969
# 2            76.0     13 August 1898
# 3            64.0        11 May 1895
# 4             NaN      17 April 1878
# ...           ...                ...
# 145495       61.0    30 January 2002
# 145496       65.0  20 September 1999
# 145497       55.0         8 May 1998
# 145498        NaN        19 May 1899
# 145499        NaN       15 July 1913
#
# [145500 rows x 20 columns]

# %%
# Extracting NOC from Born column
# df["NOC"] = df["Born"].str.extract(r'(\(\w{3}\))\s*$')
print(df[["name", "NOC"]].head())
# Out:
#                                                 name    NOC
# 0  François Joseph Marie Antoine "Jean-François" ...  (FRA)
# 1                            Arnaud Benjamin Boetsch  (FRA)
# 2                        Jean Laurent Robert Borotra  (FRA)
# 3               Jacques Marie Stanislas Jean Brugnon  (FRA)
# 4                                 Henry Albert Canet  (GBR)
